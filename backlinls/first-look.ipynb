# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/plast-surg/doctorplastic.ru.csv')
df.head()
# Out:
#    #    Referring Domain  Domain Rating  Ahrefs Rank  Total Backlinks  \
# 0  1        tecrussia.ru             49     719649.0             4358
# 1  2  plastic-review.com              9   18440722.0              612
# 2  3          molbiol.ru             62     205172.0              255
# 3  4            zbio.net             16   11144234.0              192
# 4  5     vseoplastike.ru             31    3333094.0              170
#
#    Backlinks for Referring Domain (Percent %)  Dofollow Backlinks (desc)  \
# 0                                        26.0                       4333
# 1                                         4.0                        611
# 2                                         2.0                        255
# 3                                         1.0                        192
# 4                                         1.0                        163
#
#    Dofollow Backlinks for Referring Domain (Percent %)           First Seen  \
# ...

# %%
df = pd.read_csv('datasets/plast-surg/doctorplastic.ru-anchors.csv')
df.head()
# Out:
#    #                   Anchor Text  Referring Domains Total  \
# 0  1          www.doctorplastic.ru                       60
# 1  2         пластическая хирургия                       21
# 2  3  http://www.doctorplastic.ru/                       31
# 3  4              увеличение груди                       16
# 4  5              doctorplastic.ru                       43
#
#    Referring Domains with Anchor (Percent %)  \
# 0                                       16.0
# 1                                        6.0
# 2                                        8.0
# 3                                        4.0
# 4                                       11.0
#
#    Referring Domains Dofollow (desc)  \
# 0                                 30
# 1                                 21
# 2                                 20
# 3                                 16
# 4                                 11
#
#    Referring Domains Dofollow with Anchor (Percent %)  Referring Pages Count  \
# ...
